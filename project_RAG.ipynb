# %% [markdown]
# <a href="https://colab.research.google.com/github/hieuhatinh/RAG-PM01-AIO2024/blob/feature%2Fmodel-rag/project_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q transformers==4.41.2
# !pip install -q bitsandbytes==0.43.1
# !pip install -q accelerate==0.31.0
# !pip install -q langchain==0.2.5
# !pip install -q langchainhub==0.1.20
# !pip install -q langchain-chroma==0.1.1
# !pip install -q langchain-community==0.2.5
# !pip install -q langchain-huggingface==0.0.3
# !pip install -q python-dotenv==1.0.1
# !pip install -q pypdf==4.2.0
# !pip install -q numpy==1.24.4
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 93.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 76.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 36.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 51.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.0 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 75.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.

# %%
import torch

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_huggingface.llms import HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain.chains import ConversationalRetrievalChain
from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub

# %%
Loader = PyPDFLoader
FILE_PATH = '/content/drive/MyDrive/AIO2024/Project1/Luoc_su_khoa_hoc.pdf'
loader = Loader(FILE_PATH)
documents = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,
                                                chunk_overlap=100)

# %%
docs = text_splitter.split_documents(documents)

print('Number of sub-documents: ', len(docs))
print(docs[0])
# Out:
# Number of sub-documents:  934
# page_content='WILLIAM BYNUM là giáo s ư  danh d ự  đã ngh ỉ  h ư u thu ộ c B ộ  môn L ị ch s ử  Y khoa t ạ i University\nCollege, London. Ông đã biên t ậ p cho t ạ p chí Medical History  t ừ năm 1980 đ ế n năm 2001 và\nchuyên vi ế t v ề  các khía c ạ nh c ủ a l ị ch s ử  y h ọ c cũng nh ư  khoa h ọ c c ơ  b ả n.\nÔng đang s ố ng ở  Suffolk, V ươ ng qu ố c Anh.' metadata={'source': '/content/drive/MyDrive/AIO2024/Project1/Luoc_su_khoa_hoc.pdf', 'page': 2}

# %%
embedding = HuggingFaceEmbeddings()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
vector_db = Chroma.from_documents(documents=docs,
                                  embedding=embedding)

retriever = vector_db.as_retriever()

# %%
result = retriever.invoke('Hippocrates là ai?')

print('Number of relevant documents: ', len(result))
# Out:
# Number of relevant documents:  4

# %%
nf4_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_doule_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16
)
# Out:
# Unused kwargs: ['bnb_4bit_use_doule_quant']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.

# %%
MODEL_NAME = 'lmsys/vicuna-7b-v1.5'

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=nf4_config,
    low_cpu_mem_usage=True
)

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %%
model_pipeline = pipeline(
    'text-generation',
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    pad_token_id=tokenizer.eos_token_id,
    device_map='auto'
)

llm = HuggingFacePipeline(
    pipeline=model_pipeline
)

# %%
prompt = hub.pull('rlm/rag-prompt')

def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)

rag_chain = (
    {'context': retriever | format_docs, 'question': RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

USER_QUESTION = 'Hippocrates là ai?'
output = rag_chain.invoke(USER_QUESTION)
answer = output.split('Answer:')[1].strip()
print(answer)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Hippocrates là một trong những người sáng lập ra ngành y học và được gọi là "nhà y học" trong lịch sử y học. Ông đã đưa ra một số quy tắc và phương pháp để điều trị và nghiên cứu các bệnh, và đã đóng góp rất nhiều cho sự phát triển của ngành y học.

# %% [markdown]
# ### Xây dựng giao diện chat - localtunnel

# %%
# !pip install -q transformers==4.41.2
# !pip install -q bitsandbytes==0.43.1
# !pip install -q accelerate==0.31.0
# !pip install -q langchain==0.2.5
# !pip install -q langchainhub==0.1.20
# !pip install -q langchain-chroma==0.1.1
# !pip install -q langchain-community==0.2.5
# !pip install -q langchain-openai==0.1.9
# !pip install -q langchain_huggingface==0.0.3
# !pip install -q chainlit==1.1.304
# !pip install -q python-dotenv==1.0.1
# !pip install -q pypdf==4.2.0
# !pip install -g localtunnel
# !pip install -q numpy==1.24.4
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.5/327.5 kB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 44.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 77.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.3 MB/s eta 0:00:00
#   Building wheel for literalai (setup.py) ... done
#   Building wheel for syncer (setup.py) ... done
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -g
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chainlit 1.1.304 requires numpy<2.0,>=1.26; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.

# %%
# !pip install --upgrade numpy

# %%
import chainlit as cl
import torch
from chainlit.types import AskFileResponse

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer , AutoModelForCausalLM , pipeline
from langchain_huggingface.llms import HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain.chains import ConversationalRetrievalChain

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,
                                                chunk_overlap=100)
embedding = HuggingFaceEmbeddings()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def process_file(file: AskFileResponse) :
    if file.type == "text/plain":
        Loader = TextLoader
    elif file.type == "application/pdf":
        Loader = PyPDFLoader

    loader = Loader(file.path)
    documents = loader.load()
    docs = text_splitter.split_documents(documents)
    for i, doc in enumerate(docs) :
        doc.metadata["source"] = f"source_{i}"
    return docs

# %%
def get_vector_db(file: AskFileResponse) :
    docs = process_file(file)
    cl.user_session.set ("docs", docs)
    vector_db = Chroma.from_documents(documents=docs,
                                      embedding=embedding )
    return vector_db

# %%
def get_huggingface_llm(model_name: str = "lmsys/vicuna-7b-v1.5",
                        max_new_token: int = 512):
    nf4_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type ="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16
    )
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        quantization_config=nf4_config,
        low_cpu_mem_usage=True
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    model_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=max_new_token,
        pad_token_id=tokenizer.eos_token_id,
        device_map="auto"
    )

    llm = HuggingFacePipeline(
        pipeline = model_pipeline,
    )
    return llm

LLM = get_huggingface_llm()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(

# %%
welcome_message = """Welcome to the PDF QA! To get started :
1. Upload a PDF or text file
2. Ask a question about the file
"""

# %%
@cl.on_chat_start
async def on_chat_start():
    files = None
    while files is None:
        files = await cl.AskFileMessage(
            content=welcome_message ,
            accept=["text/plain", "application/pdf"] ,
            max_size_mb=20,
            timeout=180,
        ).send()
        file = files[0]

    msg = cl.Message(content=f"Processing'{file.name}'...",
                    disable_feedback=True)
    await msg.send()

    vector_db = await cl.make_async(get_vector_db)(file)

    message_history = ChatMessageHistory()
    memory = ConversationBufferMemory(
        memory_key="chat_history",
        output_key="answer",
        chat_memory=message_history,
        return_messages=True ,
    )
    retriever = vector_db.as_retriever(search_type="mmr",
    search_kwargs={'k':3})

    chain = ConversationalRetrievalChain.from_llm(
        llm=LLM,
        chain_type="stuff",
        retriever=retriever,
        memory=memory,
        return_source_documents=True
    )

    msg.content = f" '{file.name}'processed . You can now ask questions !"
    await msg.update()

    cl.user_session.set("chain", chain)

# %%
@cl.on_message
async def on_message(message: cl.Message):
    chain = cl.user_session.get("chain")
    cb = cl.AsyncLangchainCallbackHandler()
    res = await chain.ainvoke(message.content, callbacks=[cb])
    answer = res["answer"]
    source_documents = res["source_documents"]
    text_elements = []

    if source_documents:
        for source_idx, source_doc in enumerate(source_documents):
            source_name = f"source_{source_idx}"
            text_elements.append(
                cl.Text(content=source_doc.page_content,
                        name=source_name)
            )
        source_names = [text_el.name for text_el in text_elements]

        if source_names:
            answer += f"\nSources:{','.join(source_names)}"
        else :
            answer += "\nNo sources found"

    await cl.Message(content=answer, elements=text_elements).send()

# %%
# !chainlit run app.py --host 0.0.0.0 --port 8000 &>/content/logs.txt &

# %%
import urllib

print("Password/Enpoint IP for localtunnel is:",
      urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip ("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.143.189.208

# %%
# !npm install -g localtunnel
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 3.608s

# %%
# !lt --port 8000 --subdomain aivn-simple-rag
# Out:
# your url is: https://aivn-simple-rag.loca.lt
# ^C

# %% [markdown]
# ### Xây dựng giao diện - ngrok

# %%
# !pip install -q transformers==4.41.2
# !pip install -q bitsandbytes==0.43.1
# !pip install -q accelerate==0.31.0
# !pip install -q langchain==0.2.5
# !pip install -q langchainhub==0.1.20
# !pip install -q langchain-chroma==0.1.1
# !pip install -q langchain-community==0.2.5
# !pip install -q langchain-openai==0.1.9
# !pip install -q langchain_huggingface==0.0.3
# !pip install -q chainlit==1.1.304
# !pip install -q python-dotenv==1.0.1
# !pip install -q pypdf==4.2.0
# !pip install -g localtunnel
# !pip install -q numpy==1.24.4
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 35.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 31.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 61.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.1 MB/s eta 0:00:00
#   Building wheel for literalai (setup.py) ... done
#   Building wheel for syncer (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 6.2 MB/s eta 0:00:00
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -g
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 54.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chainlit 1.1.304 requires numpy<2.0,>=1.26; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.

# %%
# %%writefile app.py

import chainlit as cl
import torch
from chainlit.types import AskFileResponse

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer , AutoModelForCausalLM , pipeline
from langchain_huggingface.llms import HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain.chains import ConversationalRetrievalChain

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub

# Khởi tạo bộ tách văn bản (text splitter)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,
                                                chunk_overlap=100)
embedding = HuggingFaceEmbeddings()

# Hàm xử lý file input đầu vào
def process_file(file: AskFileResponse) :
    if file.type == "text/plain":
        Loader = TextLoader
    elif file.type == "application/pdf":
        Loader = PyPDFLoader

    loader = Loader(file.path)
    documents = loader.load()
    docs = text_splitter.split_documents(documents)
    for i, doc in enumerate(docs) :
        doc.metadata["source"] = f"source_{i}"
    return docs


# Hàm khởi tạo Chroma database
def get_vector_db(file: AskFileResponse) :
    docs = process_file(file)
    cl.user_session.set ("docs", docs)
    vector_db = Chroma.from_documents(documents=docs,
                                      embedding=embedding )
    return vector_db


# Khởi tạo mô hình ngôn ngữ lớn
def get_huggingface_llm(model_name: str = "lmsys/vicuna-7b-v1.5",
                        max_new_token: int = 512):
    nf4_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type ="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16
    )
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        quantization_config=nf4_config,
        low_cpu_mem_usage=True
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    model_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=max_new_token,
        pad_token_id=tokenizer.eos_token_id,
        device_map="auto"
    )

    llm = HuggingFacePipeline(
        pipeline = model_pipeline,
    )
    return llm

LLM = get_huggingface_llm()


# Khởi tạo welcome message
welcome_message = """Welcome to the PDF QA! To get started :
1. Upload a PDF or text file
2. Ask a question about the file
"""

# Khởi tạo hàm on_chat_start:
@cl.on_chat_start
async def on_chat_start():
    files = None
    while files is None:
        files = await cl.AskFileMessage(
            content=welcome_message ,
            accept=["text/plain", "application/pdf"] ,
            max_size_mb=20,
            timeout=180,
        ).send()
        file = files[0]

    msg = cl.Message(content=f"Processing'{file.name}'...",
                    disable_feedback=True)
    await msg.send()

    vector_db = await cl.make_async(get_vector_db)(file)

    message_history = ChatMessageHistory()
    memory = ConversationBufferMemory(
        memory_key="chat_history",
        output_key="answer",
        chat_memory=message_history,
        return_messages=True ,
    )
    retriever = vector_db.as_retriever(search_type="mmr",
    search_kwargs={'k':3})

    chain = ConversationalRetrievalChain.from_llm(
        llm=LLM,
        chain_type="stuff",
        retriever=retriever,
        memory=memory,
        return_source_documents=True
    )

    msg.content = f" '{file.name}'processed . You can now ask questions !"
    await msg.update()

    cl.user_session.set("chain", chain)


# Khởi tạo hàm on_message
@cl.on_message
async def on_message(message: cl.Message):
    chain = cl.user_session.get("chain")
    cb = cl.AsyncLangchainCallbackHandler()
    res = await chain.ainvoke(message.content, callbacks=[cb])
    answer = res["answer"]
    source_documents = res["source_documents"]
    text_elements = []

    if source_documents:
        for source_idx, source_doc in enumerate(source_documents):
            source_name = f"source_{source_idx}"
            text_elements.append(
                cl.Text(content=source_doc.page_content,
                        name=source_name)
            )
        source_names = [text_el.name for text_el in text_elements]

        if source_names:
            answer += f"\nSources:{','.join(source_names)}"
        else :
            answer += "\nNo sources found"

    await cl.Message(content=answer, elements=text_elements).send()
# Out:
# Writing app.py

# %%
# !pip install pyngrok -q

# %%
from pyngrok import ngrok

# !ngrok config add-authtoken 2EcFdLD8RA13IbcmUMFAFjOUWiL_6Asehsfzeb6gmBRaxWEHA

public_url = ngrok.connect(8000).public_url
print(public_url)
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# https://ebae-34-16-210-175.ngrok-free.app

# %%
# !chainlit run app.py
# Out:
# 2024-07-04 16:17:52 - Created default config file at /content/.chainlit/config.toml
# 2024-07-04 16:17:52 - Created default translation directory at /content/.chainlit/translations
# 2024-07-04 16:17:52 - Created default translation file at /content/.chainlit/translations/en-US.json
# 2024-07-04 16:18:01.371903: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 16:18:01.371964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 16:18:01.504281: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-04 16:18:01.765476: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-04 16:18:05.160345: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-04 16:18:12 - Use pytorch device_name: cuda
# 2024-07-04 16:18:12 - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# modules.json: 100% 349/349 [00:00<00:00, 1.83MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 403kB/s]
# README.md: 100% 10.6k/10.6k [00:00<00:00, 34.1MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 445kB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 571/571 [00:00<00:00, 4.75MB/s]
# model.safetensors: 100% 438M/438M [00:03<00:00, 129MB/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 2.90MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.72MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 3.51MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 1.73MB/s]
# 1_Pooling/config.json: 100% 190/190 [00:00<00:00, 1.34MB/s]
# config.json: 100% 615/615 [00:00<00:00, 4.87MB/s]
# pytorch_model.bin.index.json: 100% 26.8k/26.8k [00:00<00:00, 102MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0% 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0% 31.5M/9.98G [00:00<00:39, 252MB/s]
# pytorch_model-00001-of-00002.bin:   1% 62.9M/9.98G [00:00<00:36, 273MB/s]
# pytorch_model-00001-of-00002.bin:   1% 94.4M/9.98G [00:00<00:37, 265MB/s]
# pytorch_model-00001-of-00002.bin:   1% 126M/9.98G [00:00<00:38, 259MB/s]
# pytorch_model-00001-of-00002.bin:   2% 157M/9.98G [00:00<00:39, 251MB/s]
# pytorch_model-00001-of-00002.bin:   2% 189M/9.98G [00:00<00:40, 244MB/s]
# pytorch_model-00001-of-00002.bin:   2% 220M/9.98G [00:00<00:41, 237MB/s]
# pytorch_model-00001-of-00002.bin:   3% 252M/9.98G [00:01<00:40, 239MB/s]
# pytorch_model-00001-of-00002.bin:   3% 283M/9.98G [00:01<00:41, 233MB/s]
# pytorch_model-00001-of-00002.bin:   3% 315M/9.98G [00:01<00:40, 238MB/s]
# pytorch_model-00001-of-00002.bin:   3% 346M/9.98G [00:01<00:39, 244MB/s]
# pytorch_model-00001-of-00002.bin:   4% 377M/9.98G [00:01<00:38, 250MB/s]
# pytorch_model-00001-of-00002.bin:   4% 409M/9.98G [00:01<00:37, 254MB/s]
# pytorch_model-00001-of-00002.bin:   4% 440M/9.98G [00:01<00:37, 255MB/s]
# pytorch_model-00001-of-00002.bin:   5% 472M/9.98G [00:01<00:37, 251MB/s]
# pytorch_model-00001-of-00002.bin:   5% 503M/9.98G [00:02<00:37, 256MB/s]
# pytorch_model-00001-of-00002.bin:   5% 535M/9.98G [00:02<00:36, 257MB/s]
# pytorch_model-00001-of-00002.bin:   6% 566M/9.98G [00:02<00:37, 249MB/s]
# pytorch_model-00001-of-00002.bin:   6% 598M/9.98G [00:02<00:38, 246MB/s]
# pytorch_model-00001-of-00002.bin:   6% 629M/9.98G [00:02<00:37, 248MB/s]
# pytorch_model-00001-of-00002.bin:   7% 661M/9.98G [00:02<00:36, 252MB/s]
# pytorch_model-00001-of-00002.bin:   7% 692M/9.98G [00:02<00:36, 253MB/s]
# pytorch_model-00001-of-00002.bin:   7% 724M/9.98G [00:02<00:37, 248MB/s]
# pytorch_model-00001-of-00002.bin:   8% 755M/9.98G [00:03<00:36, 251MB/s]
# pytorch_model-00001-of-00002.bin:   8% 786M/9.98G [00:03<00:37, 244MB/s]
# pytorch_model-00001-of-00002.bin:   8% 818M/9.98G [00:03<00:36, 249MB/s]
# pytorch_model-00001-of-00002.bin:   9% 849M/9.98G [00:03<00:35, 254MB/s]
# pytorch_model-00001-of-00002.bin:   9% 881M/9.98G [00:03<00:36, 249MB/s]
# pytorch_model-00001-of-00002.bin:   9% 912M/9.98G [00:03<00:36, 248MB/s]
# pytorch_model-00001-of-00002.bin:   9% 944M/9.98G [00:03<00:36, 250MB/s]
# pytorch_model-00001-of-00002.bin:  10% 975M/9.98G [00:03<00:36, 245MB/s]
# pytorch_model-00001-of-00002.bin:  10% 1.01G/9.98G [00:04<00:35, 252MB/s]
# pytorch_model-00001-of-00002.bin:  10% 1.04G/9.98G [00:04<00:36, 247MB/s]
# pytorch_model-00001-of-00002.bin:  11% 1.07G/9.98G [00:04<00:35, 252MB/s]
# pytorch_model-00001-of-00002.bin:  11% 1.10G/9.98G [00:04<00:34, 259MB/s]
# pytorch_model-00001-of-00002.bin:  11% 1.13G/9.98G [00:04<00:35, 252MB/s]
# pytorch_model-00001-of-00002.bin:  12% 1.16G/9.98G [00:04<00:35, 250MB/s]
# pytorch_model-00001-of-00002.bin:  12% 1.20G/9.98G [00:04<00:35, 246MB/s]
# pytorch_model-00001-of-00002.bin:  12% 1.23G/9.98G [00:04<00:36, 242MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.26G/9.98G [00:05<00:34, 250MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.29G/9.98G [00:05<00:35, 247MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.32G/9.98G [00:05<00:35, 243MB/s]
# pytorch_model-00001-of-00002.bin:  14% 1.35G/9.98G [00:05<00:35, 245MB/s]
# pytorch_model-00001-of-00002.bin:  14% 1.38G/9.98G [00:05<00:33, 253MB/s]
# pytorch_model-00001-of-00002.bin:  14% 1.42G/9.98G [00:05<00:34, 248MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.45G/9.98G [00:06<00:51, 166MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.48G/9.98G [00:06<00:44, 190MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.51G/9.98G [00:06<00:40, 210MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.54G/9.98G [00:06<00:37, 227MB/s]
# pytorch_model-00001-of-00002.bin:  16% 1.57G/9.98G [00:06<00:40, 209MB/s]
# pytorch_model-00001-of-00002.bin:  16% 1.60G/9.98G [00:06<00:40, 208MB/s]
# pytorch_model-00001-of-00002.bin:  16% 1.64G/9.98G [00:06<00:39, 209MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.67G/9.98G [00:06<00:38, 216MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.70G/9.98G [00:07<00:36, 225MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.73G/9.98G [00:07<00:38, 214MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.76G/9.98G [00:07<00:40, 202MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.78G/9.98G [00:07<00:40, 203MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.81G/9.98G [00:07<00:39, 206MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.84G/9.98G [00:07<00:39, 204MB/s]
# pytorch_model-00001-of-00002.bin:  19% 1.86G/9.98G [00:10<04:09, 32.6MB/s]
# pytorch_model-00001-of-00002.bin:  19% 1.89G/9.98G [00:10<02:51, 47.3MB/s]
# pytorch_model-00001-of-00002.bin:  19% 1.92G/9.98G [00:10<02:02, 65.6MB/s]
# pytorch_model-00001-of-00002.bin:  20% 1.95G/9.98G [00:10<01:35, 84.2MB/s]
# pytorch_model-00001-of-00002.bin:  20% 1.98G/9.98G [00:10<01:16, 105MB/s]
# pytorch_model-00001-of-00002.bin:  20% 2.01G/9.98G [00:10<01:04, 124MB/s]
# pytorch_model-00001-of-00002.bin:  20% 2.04G/9.98G [00:10<00:53, 148MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.08G/9.98G [00:10<00:47, 167MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.11G/9.98G [00:11<00:42, 185MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.14G/9.98G [00:11<00:38, 202MB/s]
# pytorch_model-00001-of-00002.bin:  22% 2.17G/9.98G [00:11<00:39, 198MB/s]
# pytorch_model-00001-of-00002.bin:  22% 2.20G/9.98G [00:11<00:36, 210MB/s]
# pytorch_model-00001-of-00002.bin:  22% 2.23G/9.98G [00:11<00:34, 227MB/s]
# pytorch_model-00001-of-00002.bin:  23% 2.26G/9.98G [00:11<00:33, 231MB/s]
# pytorch_model-00001-of-00002.bin:  23% 2.30G/9.98G [00:11<00:34, 225MB/s]
# pytorch_model-00001-of-00002.bin:  23% 2.33G/9.98G [00:12<00:32, 233MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.36G/9.98G [00:12<00:33, 227MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.39G/9.98G [00:13<01:50, 68.8MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.42G/9.98G [00:13<01:25, 88.3MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.44G/9.98G [00:13<01:19, 94.5MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.46G/9.98G [00:13<01:15, 99.4MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.49G/9.98G [00:14<01:12, 103MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.51G/9.98G [00:14<01:07, 111MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.53G/9.98G [00:14<00:59, 125MB/s]
# pytorch_model-00001-of-00002.bin:  26% 2.55G/9.98G [00:14<00:52, 141MB/s]
# pytorch_model-00001-of-00002.bin:  26% 2.58G/9.98G [00:14<00:44, 168MB/s]
# pytorch_model-00001-of-00002.bin:  26% 2.61G/9.98G [00:14<00:39, 189MB/s]
# pytorch_model-00001-of-00002.bin:  26% 2.64G/9.98G [00:14<00:36, 204MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.67G/9.98G [00:14<00:33, 220MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.71G/9.98G [00:14<00:31, 234MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.74G/9.98G [00:15<00:30, 237MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.77G/9.98G [00:15<00:30, 237MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.80G/9.98G [00:15<00:29, 245MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.83G/9.98G [00:15<00:28, 252MB/s]
# pytorch_model-00001-of-00002.bin:  29% 2.86G/9.98G [00:15<00:29, 241MB/s]
# pytorch_model-00001-of-00002.bin:  29% 2.89G/9.98G [00:15<00:29, 243MB/s]
# pytorch_model-00001-of-00002.bin:  29% 2.93G/9.98G [00:15<00:28, 248MB/s]
# pytorch_model-00001-of-00002.bin:  30% 2.96G/9.98G [00:16<00:29, 237MB/s]
# pytorch_model-00001-of-00002.bin:  30% 2.99G/9.98G [00:16<00:28, 241MB/s]
# pytorch_model-00001-of-00002.bin:  30% 3.02G/9.98G [00:16<00:28, 240MB/s]
# pytorch_model-00001-of-00002.bin:  31% 3.05G/9.98G [00:16<00:41, 166MB/s]
# pytorch_model-00001-of-00002.bin:  31% 3.08G/9.98G [00:16<00:36, 190MB/s]
# pytorch_model-00001-of-00002.bin:  31% 3.11G/9.98G [00:16<00:33, 203MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.15G/9.98G [00:16<00:32, 209MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.18G/9.98G [00:17<00:30, 224MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.21G/9.98G [00:17<00:30, 222MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.24G/9.98G [00:20<03:41, 30.4MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.26G/9.98G [00:20<03:00, 37.2MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.29G/9.98G [00:20<02:11, 50.8MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.32G/9.98G [00:20<01:38, 67.3MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.34G/9.98G [00:20<01:25, 78.0MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.37G/9.98G [00:21<01:11, 92.1MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.39G/9.98G [00:22<02:46, 39.5MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.41G/9.98G [00:22<02:09, 50.6MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.44G/9.98G [00:22<01:31, 71.5MB/s]
# pytorch_model-00001-of-00002.bin:  35% 3.47G/9.98G [00:22<01:07, 96.1MB/s]
# pytorch_model-00001-of-00002.bin:  35% 3.50G/9.98G [00:24<02:24, 44.7MB/s]
# pytorch_model-00001-of-00002.bin:  35% 3.52G/9.98G [00:24<01:59, 54.0MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.55G/9.98G [00:24<01:27, 73.5MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.59G/9.98G [00:24<01:06, 96.8MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.62G/9.98G [00:24<00:52, 121MB/s]
# pytorch_model-00001-of-00002.bin:  37% 3.65G/9.98G [00:24<00:45, 138MB/s]
# pytorch_model-00001-of-00002.bin:  37% 3.68G/9.98G [00:24<00:39, 161MB/s]
# pytorch_model-00001-of-00002.bin:  37% 3.71G/9.98G [00:25<00:34, 183MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.74G/9.98G [00:25<00:31, 200MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.77G/9.98G [00:25<00:29, 211MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.81G/9.98G [00:25<00:28, 219MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.84G/9.98G [00:25<00:26, 230MB/s]
# pytorch_model-00001-of-00002.bin:  39% 3.87G/9.98G [00:25<00:25, 237MB/s]
# pytorch_model-00001-of-00002.bin:  39% 3.90G/9.98G [00:25<00:24, 243MB/s]
# pytorch_model-00001-of-00002.bin:  39% 3.93G/9.98G [00:25<00:24, 249MB/s]
# pytorch_model-00001-of-00002.bin:  40% 3.96G/9.98G [00:26<00:23, 251MB/s]
# pytorch_model-00001-of-00002.bin:  40% 4.00G/9.98G [00:26<00:23, 251MB/s]
# pytorch_model-00001-of-00002.bin:  40% 4.03G/9.98G [00:26<00:23, 256MB/s]
# pytorch_model-00001-of-00002.bin:  41% 4.06G/9.98G [00:26<00:23, 253MB/s]
# pytorch_model-00001-of-00002.bin:  41% 4.09G/9.98G [00:26<00:24, 245MB/s]
# pytorch_model-00001-of-00002.bin:  41% 4.12G/9.98G [00:26<00:23, 249MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.15G/9.98G [00:26<00:23, 253MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.18G/9.98G [00:26<00:22, 257MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.22G/9.98G [00:27<00:22, 260MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.25G/9.98G [00:27<00:22, 258MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.28G/9.98G [00:27<00:22, 258MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.31G/9.98G [00:27<00:22, 248MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.34G/9.98G [00:27<00:23, 241MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.37G/9.98G [00:27<00:22, 249MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.40G/9.98G [00:27<00:22, 246MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.44G/9.98G [00:27<00:22, 250MB/s]
# pytorch_model-00001-of-00002.bin:  45% 4.47G/9.98G [00:28<00:23, 236MB/s]
# pytorch_model-00001-of-00002.bin:  45% 4.50G/9.98G [00:28<00:22, 242MB/s]
# pytorch_model-00001-of-00002.bin:  45% 4.53G/9.98G [00:28<00:21, 252MB/s]
# pytorch_model-00001-of-00002.bin:  46% 4.56G/9.98G [00:28<00:21, 254MB/s]
# pytorch_model-00001-of-00002.bin:  46% 4.59G/9.98G [00:28<00:21, 255MB/s]
# pytorch_model-00001-of-00002.bin:  46% 4.62G/9.98G [00:28<00:20, 259MB/s]
# pytorch_model-00001-of-00002.bin:  47% 4.66G/9.98G [00:28<00:21, 253MB/s]
# pytorch_model-00001-of-00002.bin:  47% 4.69G/9.98G [00:28<00:20, 252MB/s]
# pytorch_model-00001-of-00002.bin:  47% 4.72G/9.98G [00:29<00:20, 251MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.75G/9.98G [00:29<00:20, 252MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.78G/9.98G [00:29<00:21, 246MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.81G/9.98G [00:29<00:20, 255MB/s]
# pytorch_model-00001-of-00002.bin:  49% 4.84G/9.98G [00:29<00:20, 252MB/s]
# pytorch_model-00001-of-00002.bin:  49% 4.88G/9.98G [00:29<00:21, 242MB/s]
# pytorch_model-00001-of-00002.bin:  49% 4.91G/9.98G [00:29<00:21, 236MB/s]
# pytorch_model-00001-of-00002.bin:  50% 4.94G/9.98G [00:29<00:20, 242MB/s]
# pytorch_model-00001-of-00002.bin:  50% 4.97G/9.98G [00:30<00:20, 245MB/s]
# pytorch_model-00001-of-00002.bin:  50% 5.00G/9.98G [00:30<00:20, 247MB/s]
# pytorch_model-00001-of-00002.bin:  50% 5.03G/9.98G [00:30<00:19, 255MB/s]
# pytorch_model-00001-of-00002.bin:  51% 5.06G/9.98G [00:30<00:19, 254MB/s]
# pytorch_model-00001-of-00002.bin:  51% 5.10G/9.98G [00:30<00:19, 247MB/s]
# pytorch_model-00001-of-00002.bin:  51% 5.13G/9.98G [00:30<00:20, 240MB/s]
# pytorch_model-00001-of-00002.bin:  52% 5.16G/9.98G [00:30<00:20, 237MB/s]
# pytorch_model-00001-of-00002.bin:  52% 5.19G/9.98G [00:31<00:19, 242MB/s]
# pytorch_model-00001-of-00002.bin:  52% 5.22G/9.98G [00:31<00:18, 251MB/s]
# pytorch_model-00001-of-00002.bin:  53% 5.25G/9.98G [00:31<00:18, 253MB/s]
# pytorch_model-00001-of-00002.bin:  53% 5.28G/9.98G [00:31<00:17, 262MB/s]
# pytorch_model-00001-of-00002.bin:  53% 5.32G/9.98G [00:31<00:17, 260MB/s]
# pytorch_model-00001-of-00002.bin:  54% 5.35G/9.98G [00:31<00:18, 251MB/s]
# pytorch_model-00001-of-00002.bin:  54% 5.38G/9.98G [00:31<00:19, 238MB/s]
# pytorch_model-00001-of-00002.bin:  54% 5.41G/9.98G [00:31<00:20, 223MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.44G/9.98G [00:32<00:19, 232MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.47G/9.98G [00:32<00:19, 232MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.51G/9.98G [00:32<00:21, 212MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.54G/9.98G [00:32<00:22, 193MB/s]
# pytorch_model-00001-of-00002.bin:  56% 5.56G/9.98G [00:32<00:23, 190MB/s]
# pytorch_model-00001-of-00002.bin:  56% 5.58G/9.98G [00:32<00:22, 192MB/s]
# pytorch_model-00001-of-00002.bin:  56% 5.61G/9.98G [00:32<00:21, 206MB/s]
# pytorch_model-00001-of-00002.bin:  57% 5.64G/9.98G [00:33<00:20, 210MB/s]
# pytorch_model-00001-of-00002.bin:  57% 5.67G/9.98G [00:33<00:29, 146MB/s]
# pytorch_model-00001-of-00002.bin:  57% 5.70G/9.98G [00:33<00:25, 165MB/s]
# pytorch_model-00001-of-00002.bin:  57% 5.74G/9.98G [00:33<00:23, 184MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.77G/9.98G [00:33<00:22, 191MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.79G/9.98G [00:33<00:22, 188MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.81G/9.98G [00:34<00:22, 183MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.83G/9.98G [00:34<00:22, 188MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.85G/9.98G [00:34<00:21, 189MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.87G/9.98G [00:34<00:22, 181MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.89G/9.98G [00:34<00:21, 188MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.92G/9.98G [00:34<00:20, 198MB/s]
# pytorch_model-00001-of-00002.bin:  60% 5.95G/9.98G [00:34<00:21, 187MB/s]
# pytorch_model-00001-of-00002.bin:  60% 5.98G/9.98G [00:34<00:19, 201MB/s]
# pytorch_model-00001-of-00002.bin:  60% 6.01G/9.98G [00:35<00:18, 209MB/s]
# pytorch_model-00001-of-00002.bin:  60% 6.03G/9.98G [00:35<00:19, 203MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.05G/9.98G [00:35<00:20, 188MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.07G/9.98G [00:35<00:20, 186MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.09G/9.98G [00:35<00:20, 190MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.12G/9.98G [00:35<00:19, 200MB/s]
# pytorch_model-00001-of-00002.bin:  62% 6.16G/9.98G [00:35<00:18, 210MB/s]
# pytorch_model-00001-of-00002.bin:  62% 6.19G/9.98G [00:35<00:17, 217MB/s]
# pytorch_model-00001-of-00002.bin:  62% 6.22G/9.98G [00:36<00:17, 220MB/s]
# pytorch_model-00001-of-00002.bin:  63% 6.25G/9.98G [00:36<00:16, 228MB/s]
# pytorch_model-00001-of-00002.bin:  63% 6.28G/9.98G [00:36<00:15, 232MB/s]
# pytorch_model-00001-of-00002.bin:  63% 6.31G/9.98G [00:36<00:15, 239MB/s]
# pytorch_model-00001-of-00002.bin:  64% 6.34G/9.98G [00:36<00:14, 248MB/s]
# pytorch_model-00001-of-00002.bin:  64% 6.38G/9.98G [00:36<00:14, 241MB/s]
# pytorch_model-00001-of-00002.bin:  64% 6.41G/9.98G [00:36<00:14, 252MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.44G/9.98G [00:36<00:13, 260MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.47G/9.98G [00:37<00:14, 239MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.50G/9.98G [00:37<00:14, 242MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.53G/9.98G [00:37<00:14, 245MB/s]
# pytorch_model-00001-of-00002.bin:  66% 6.56G/9.98G [00:37<00:14, 232MB/s]
# pytorch_model-00001-of-00002.bin:  66% 6.60G/9.98G [00:37<00:13, 243MB/s]
# pytorch_model-00001-of-00002.bin:  66% 6.63G/9.98G [00:37<00:13, 252MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.66G/9.98G [00:37<00:13, 249MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.69G/9.98G [00:37<00:12, 257MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.72G/9.98G [00:38<00:12, 253MB/s]
# pytorch_model-00001-of-00002.bin:  68% 6.75G/9.98G [00:38<00:13, 246MB/s]
# pytorch_model-00001-of-00002.bin:  68% 6.78G/9.98G [00:38<00:12, 248MB/s]
# pytorch_model-00001-of-00002.bin:  68% 6.82G/9.98G [00:38<00:12, 252MB/s]
# pytorch_model-00001-of-00002.bin:  69% 6.85G/9.98G [00:38<00:12, 249MB/s]
# pytorch_model-00001-of-00002.bin:  69% 6.88G/9.98G [00:38<00:12, 252MB/s]
# pytorch_model-00001-of-00002.bin:  69% 6.91G/9.98G [00:38<00:12, 249MB/s]
# pytorch_model-00001-of-00002.bin:  70% 6.94G/9.98G [00:39<00:12, 248MB/s]
# pytorch_model-00001-of-00002.bin:  70% 6.97G/9.98G [00:39<00:12, 248MB/s]
# pytorch_model-00001-of-00002.bin:  70% 7.00G/9.98G [00:39<00:12, 247MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.04G/9.98G [00:39<00:11, 249MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.07G/9.98G [00:39<00:11, 252MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.10G/9.98G [00:39<00:11, 258MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.13G/9.98G [00:39<00:11, 246MB/s]
# pytorch_model-00001-of-00002.bin:  72% 7.16G/9.98G [00:39<00:12, 235MB/s]
# pytorch_model-00001-of-00002.bin:  72% 7.19G/9.98G [00:40<00:11, 232MB/s]
# pytorch_model-00001-of-00002.bin:  72% 7.22G/9.98G [00:40<00:11, 243MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.26G/9.98G [00:40<00:11, 243MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.29G/9.98G [00:40<00:10, 250MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.32G/9.98G [00:40<00:10, 249MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.35G/9.98G [00:40<00:12, 212MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.38G/9.98G [00:41<00:15, 164MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.40G/9.98G [00:41<00:16, 160MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.42G/9.98G [00:41<00:18, 136MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.44G/9.98G [00:41<00:18, 134MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.47G/9.98G [00:41<00:21, 117MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.49G/9.98G [00:42<00:26, 92.7MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.51G/9.98G [00:42<00:23, 104MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.53G/9.98G [00:42<00:20, 117MB/s]
# pytorch_model-00001-of-00002.bin:  76% 7.55G/9.98G [00:42<00:21, 113MB/s]
# pytorch_model-00001-of-00002.bin:  76% 7.57G/9.98G [00:42<00:18, 128MB/s]
# pytorch_model-00001-of-00002.bin:  76% 7.60G/9.98G [00:42<00:15, 154MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.63G/9.98G [00:43<00:13, 170MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.67G/9.98G [00:43<00:13, 169MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.69G/9.98G [00:43<00:16, 137MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.71G/9.98G [00:43<00:17, 129MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.73G/9.98G [00:44<00:32, 69.4MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.76G/9.98G [00:44<00:23, 93.4MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.79G/9.98G [00:44<00:18, 119MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.82G/9.98G [00:44<00:15, 143MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.85G/9.98G [00:44<00:12, 166MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.89G/9.98G [00:44<00:11, 181MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.92G/9.98G [00:45<00:10, 199MB/s]
# pytorch_model-00001-of-00002.bin:  80% 7.95G/9.98G [00:45<00:09, 209MB/s]
# pytorch_model-00001-of-00002.bin:  80% 7.98G/9.98G [00:45<00:08, 224MB/s]
# pytorch_model-00001-of-00002.bin:  80% 8.01G/9.98G [00:45<00:08, 223MB/s]
# pytorch_model-00001-of-00002.bin:  81% 8.04G/9.98G [00:45<00:08, 230MB/s]
# pytorch_model-00001-of-00002.bin:  81% 8.07G/9.98G [00:45<00:08, 232MB/s]
# pytorch_model-00001-of-00002.bin:  81% 8.11G/9.98G [00:45<00:08, 224MB/s]
# pytorch_model-00001-of-00002.bin:  82% 8.14G/9.98G [00:46<00:08, 228MB/s]
# pytorch_model-00001-of-00002.bin:  82% 8.17G/9.98G [00:46<00:07, 235MB/s]
# pytorch_model-00001-of-00002.bin:  82% 8.20G/9.98G [00:46<00:08, 219MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.23G/9.98G [00:46<00:08, 207MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.26G/9.98G [00:46<00:08, 206MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.29G/9.98G [00:46<00:07, 211MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.33G/9.98G [00:46<00:08, 206MB/s]
# pytorch_model-00001-of-00002.bin:  84% 8.35G/9.98G [00:47<00:07, 204MB/s]
# pytorch_model-00001-of-00002.bin:  84% 8.38G/9.98G [00:47<00:07, 206MB/s]
# pytorch_model-00001-of-00002.bin:  84% 8.40G/9.98G [00:47<00:07, 206MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.43G/9.98G [00:47<00:07, 215MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.46G/9.98G [00:47<00:07, 205MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.49G/9.98G [00:47<00:06, 214MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.52G/9.98G [00:47<00:06, 220MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.56G/9.98G [00:48<00:07, 200MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.58G/9.98G [00:48<00:07, 186MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.60G/9.98G [00:48<00:07, 190MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.63G/9.98G [00:48<00:06, 200MB/s]
# pytorch_model-00001-of-00002.bin:  87% 8.66G/9.98G [00:48<00:06, 213MB/s]
# pytorch_model-00001-of-00002.bin:  87% 8.69G/9.98G [00:48<00:06, 209MB/s]
# pytorch_model-00001-of-00002.bin:  87% 8.72G/9.98G [00:48<00:06, 202MB/s]
# pytorch_model-00001-of-00002.bin:  88% 8.76G/9.98G [00:49<00:05, 210MB/s]
# pytorch_model-00001-of-00002.bin:  88% 8.79G/9.98G [00:49<00:05, 205MB/s]
# pytorch_model-00001-of-00002.bin:  88% 8.82G/9.98G [00:49<00:07, 149MB/s]
# pytorch_model-00001-of-00002.bin:  89% 8.85G/9.98G [00:49<00:06, 169MB/s]
# pytorch_model-00001-of-00002.bin:  89% 8.88G/9.98G [00:49<00:05, 186MB/s]
# pytorch_model-00001-of-00002.bin:  89% 8.90G/9.98G [00:49<00:05, 183MB/s]
# pytorch_model-00001-of-00002.bin:  90% 8.93G/9.98G [00:50<00:05, 197MB/s]
# pytorch_model-00001-of-00002.bin:  90% 8.97G/9.98G [00:50<00:04, 208MB/s]
# pytorch_model-00001-of-00002.bin:  90% 9.00G/9.98G [00:50<00:04, 218MB/s]
# pytorch_model-00001-of-00002.bin:  90% 9.03G/9.98G [00:50<00:04, 222MB/s]
# pytorch_model-00001-of-00002.bin:  91% 9.06G/9.98G [00:50<00:04, 228MB/s]
# pytorch_model-00001-of-00002.bin:  91% 9.09G/9.98G [00:50<00:03, 230MB/s]
# pytorch_model-00001-of-00002.bin:  91% 9.12G/9.98G [00:50<00:04, 208MB/s]
# pytorch_model-00001-of-00002.bin:  92% 9.15G/9.98G [00:51<00:03, 219MB/s]
# pytorch_model-00001-of-00002.bin:  92% 9.19G/9.98G [00:51<00:03, 232MB/s]
# pytorch_model-00001-of-00002.bin:  92% 9.22G/9.98G [00:51<00:03, 240MB/s]
# pytorch_model-00001-of-00002.bin:  93% 9.25G/9.98G [00:51<00:03, 237MB/s]
# pytorch_model-00001-of-00002.bin:  93% 9.28G/9.98G [00:51<00:02, 242MB/s]
# pytorch_model-00001-of-00002.bin:  93% 9.31G/9.98G [00:51<00:02, 248MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.34G/9.98G [00:51<00:02, 247MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.37G/9.98G [00:51<00:02, 246MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.41G/9.98G [00:52<00:02, 245MB/s]
# pytorch_model-00001-of-00002.bin:  95% 9.44G/9.98G [00:52<00:02, 258MB/s]
# pytorch_model-00001-of-00002.bin:  95% 9.47G/9.98G [00:52<00:02, 245MB/s]
# pytorch_model-00001-of-00002.bin:  95% 9.50G/9.98G [00:52<00:01, 246MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.53G/9.98G [00:52<00:01, 247MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.56G/9.98G [00:55<00:11, 36.7MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.59G/9.98G [00:55<00:07, 49.6MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.63G/9.98G [00:55<00:05, 65.9MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.66G/9.98G [00:55<00:03, 85.8MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.69G/9.98G [00:55<00:02, 105MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.72G/9.98G [00:55<00:02, 123MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.75G/9.98G [00:55<00:01, 142MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.78G/9.98G [00:56<00:01, 162MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.81G/9.98G [00:56<00:00, 182MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.85G/9.98G [00:56<00:00, 194MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.88G/9.98G [00:56<00:00, 209MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.91G/9.98G [00:56<00:00, 223MB/s]
# pytorch_model-00001-of-00002.bin: 100% 9.94G/9.98G [00:56<00:00, 226MB/s]
# pytorch_model-00001-of-00002.bin: 100% 9.98G/9.98G [00:56<00:00, 176MB/s]
# Downloading shards:  50% 1/2 [00:56<00:56, 56.95s/it]
# pytorch_model-00002-of-00002.bin:   0% 0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   1% 21.0M/3.50G [00:00<00:24, 144MB/s]
# pytorch_model-00002-of-00002.bin:   1% 41.9M/3.50G [00:00<00:21, 165MB/s]
# pytorch_model-00002-of-00002.bin:   2% 73.4M/3.50G [00:00<00:17, 201MB/s]
# pytorch_model-00002-of-00002.bin:   3% 105M/3.50G [00:00<00:14, 231MB/s]
# pytorch_model-00002-of-00002.bin:   4% 136M/3.50G [00:00<00:14, 224MB/s]
# pytorch_model-00002-of-00002.bin:   5% 168M/3.50G [00:00<00:14, 223MB/s]
# pytorch_model-00002-of-00002.bin:   6% 199M/3.50G [00:00<00:13, 237MB/s]
# pytorch_model-00002-of-00002.bin:   7% 231M/3.50G [00:04<02:00, 27.0MB/s]
# pytorch_model-00002-of-00002.bin:   7% 262M/3.50G [00:04<01:25, 37.8MB/s]
# pytorch_model-00002-of-00002.bin:   8% 294M/3.50G [00:04<01:02, 51.5MB/s]
# pytorch_model-00002-of-00002.bin:   9% 325M/3.50G [00:04<00:46, 67.9MB/s]
# pytorch_model-00002-of-00002.bin:  10% 357M/3.50G [00:04<00:38, 81.7MB/s]
# pytorch_model-00002-of-00002.bin:  11% 377M/3.50G [00:04<00:33, 94.3MB/s]
# pytorch_model-00002-of-00002.bin:  11% 398M/3.50G [00:05<00:28, 107MB/s]
# pytorch_model-00002-of-00002.bin:  12% 419M/3.50G [00:05<00:26, 118MB/s]
# pytorch_model-00002-of-00002.bin:  13% 440M/3.50G [00:05<00:23, 128MB/s]
# pytorch_model-00002-of-00002.bin:  13% 461M/3.50G [00:05<00:21, 142MB/s]
# pytorch_model-00002-of-00002.bin:  14% 493M/3.50G [00:05<00:18, 164MB/s]
# pytorch_model-00002-of-00002.bin:  15% 524M/3.50G [00:05<00:16, 184MB/s]
# pytorch_model-00002-of-00002.bin:  16% 556M/3.50G [00:05<00:14, 201MB/s]
# pytorch_model-00002-of-00002.bin:  17% 587M/3.50G [00:05<00:15, 189MB/s]
# pytorch_model-00002-of-00002.bin:  17% 608M/3.50G [00:06<00:15, 182MB/s]
# pytorch_model-00002-of-00002.bin:  18% 640M/3.50G [00:06<00:14, 194MB/s]
# pytorch_model-00002-of-00002.bin:  19% 661M/3.50G [00:07<00:44, 63.8MB/s]
# pytorch_model-00002-of-00002.bin:  19% 682M/3.50G [00:07<00:40, 69.9MB/s]
# pytorch_model-00002-of-00002.bin:  20% 713M/3.50G [00:07<00:29, 93.0MB/s]
# pytorch_model-00002-of-00002.bin:  21% 744M/3.50G [00:07<00:23, 117MB/s]
# pytorch_model-00002-of-00002.bin:  22% 776M/3.50G [00:07<00:19, 138MB/s]
# pytorch_model-00002-of-00002.bin:  23% 807M/3.50G [00:08<00:16, 160MB/s]
# pytorch_model-00002-of-00002.bin:  24% 839M/3.50G [00:08<00:15, 174MB/s]
# pytorch_model-00002-of-00002.bin:  25% 870M/3.50G [00:08<00:13, 190MB/s]
# pytorch_model-00002-of-00002.bin:  26% 902M/3.50G [00:08<00:12, 206MB/s]
# pytorch_model-00002-of-00002.bin:  27% 933M/3.50G [00:08<00:11, 218MB/s]
# pytorch_model-00002-of-00002.bin:  28% 965M/3.50G [00:08<00:11, 223MB/s]
# pytorch_model-00002-of-00002.bin:  28% 996M/3.50G [00:08<00:10, 232MB/s]
# pytorch_model-00002-of-00002.bin:  29% 1.03G/3.50G [00:08<00:10, 233MB/s]
# pytorch_model-00002-of-00002.bin:  30% 1.06G/3.50G [00:09<00:10, 227MB/s]
# pytorch_model-00002-of-00002.bin:  31% 1.09G/3.50G [00:09<00:10, 232MB/s]
# pytorch_model-00002-of-00002.bin:  32% 1.12G/3.50G [00:09<00:10, 235MB/s]
# pytorch_model-00002-of-00002.bin:  33% 1.15G/3.50G [00:09<00:10, 231MB/s]
# pytorch_model-00002-of-00002.bin:  34% 1.18G/3.50G [00:09<00:09, 233MB/s]
# pytorch_model-00002-of-00002.bin:  35% 1.22G/3.50G [00:09<00:09, 233MB/s]
# pytorch_model-00002-of-00002.bin:  36% 1.25G/3.50G [00:09<00:09, 238MB/s]
# pytorch_model-00002-of-00002.bin:  37% 1.28G/3.50G [00:09<00:09, 240MB/s]
# pytorch_model-00002-of-00002.bin:  37% 1.31G/3.50G [00:10<00:08, 249MB/s]
# pytorch_model-00002-of-00002.bin:  38% 1.34G/3.50G [00:10<00:08, 243MB/s]
# pytorch_model-00002-of-00002.bin:  39% 1.37G/3.50G [00:10<00:10, 198MB/s]
# pytorch_model-00002-of-00002.bin:  40% 1.41G/3.50G [00:10<00:09, 211MB/s]
# pytorch_model-00002-of-00002.bin:  41% 1.44G/3.50G [00:10<00:09, 213MB/s]
# pytorch_model-00002-of-00002.bin:  42% 1.47G/3.50G [00:10<00:09, 219MB/s]
# pytorch_model-00002-of-00002.bin:  43% 1.50G/3.50G [00:11<00:09, 222MB/s]
# pytorch_model-00002-of-00002.bin:  44% 1.53G/3.50G [00:11<00:08, 225MB/s]
# pytorch_model-00002-of-00002.bin:  45% 1.56G/3.50G [00:11<00:08, 221MB/s]
# pytorch_model-00002-of-00002.bin:  46% 1.59G/3.50G [00:11<00:08, 225MB/s]
# pytorch_model-00002-of-00002.bin:  46% 1.63G/3.50G [00:11<00:08, 232MB/s]
# pytorch_model-00002-of-00002.bin:  47% 1.66G/3.50G [00:11<00:07, 235MB/s]
# pytorch_model-00002-of-00002.bin:  48% 1.69G/3.50G [00:11<00:07, 235MB/s]
# pytorch_model-00002-of-00002.bin:  49% 1.72G/3.50G [00:11<00:07, 240MB/s]
# pytorch_model-00002-of-00002.bin:  50% 1.75G/3.50G [00:12<00:07, 243MB/s]
# pytorch_model-00002-of-00002.bin:  51% 1.78G/3.50G [00:12<00:07, 245MB/s]
# pytorch_model-00002-of-00002.bin:  52% 1.81G/3.50G [00:12<00:07, 235MB/s]
# pytorch_model-00002-of-00002.bin:  53% 1.85G/3.50G [00:12<00:06, 238MB/s]
# pytorch_model-00002-of-00002.bin:  54% 1.88G/3.50G [00:12<00:06, 240MB/s]
# pytorch_model-00002-of-00002.bin:  55% 1.91G/3.50G [00:12<00:06, 246MB/s]
# pytorch_model-00002-of-00002.bin:  55% 1.94G/3.50G [00:12<00:06, 252MB/s]
# pytorch_model-00002-of-00002.bin:  56% 1.97G/3.50G [00:12<00:06, 231MB/s]
# pytorch_model-00002-of-00002.bin:  57% 2.00G/3.50G [00:13<00:06, 236MB/s]
# pytorch_model-00002-of-00002.bin:  58% 2.03G/3.50G [00:13<00:06, 238MB/s]
# pytorch_model-00002-of-00002.bin:  59% 2.07G/3.50G [00:13<00:06, 227MB/s]
# pytorch_model-00002-of-00002.bin:  60% 2.10G/3.50G [00:13<00:05, 237MB/s]
# pytorch_model-00002-of-00002.bin:  61% 2.13G/3.50G [00:13<00:05, 241MB/s]
# pytorch_model-00002-of-00002.bin:  62% 2.16G/3.50G [00:13<00:05, 246MB/s]
# pytorch_model-00002-of-00002.bin:  63% 2.19G/3.50G [00:13<00:05, 244MB/s]
# pytorch_model-00002-of-00002.bin:  64% 2.22G/3.50G [00:14<00:05, 241MB/s]
# pytorch_model-00002-of-00002.bin:  64% 2.25G/3.50G [00:14<00:04, 253MB/s]
# pytorch_model-00002-of-00002.bin:  65% 2.29G/3.50G [00:14<00:04, 260MB/s]
# pytorch_model-00002-of-00002.bin:  66% 2.32G/3.50G [00:14<00:05, 222MB/s]
# pytorch_model-00002-of-00002.bin:  67% 2.35G/3.50G [00:14<00:05, 223MB/s]
# pytorch_model-00002-of-00002.bin:  68% 2.38G/3.50G [00:14<00:04, 236MB/s]
# pytorch_model-00002-of-00002.bin:  69% 2.41G/3.50G [00:14<00:04, 239MB/s]
# pytorch_model-00002-of-00002.bin:  70% 2.44G/3.50G [00:14<00:04, 241MB/s]
# pytorch_model-00002-of-00002.bin:  71% 2.47G/3.50G [00:15<00:04, 246MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.51G/3.50G [00:15<00:04, 245MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.54G/3.50G [00:15<00:03, 251MB/s]
# pytorch_model-00002-of-00002.bin:  73% 2.57G/3.50G [00:15<00:03, 247MB/s]
# pytorch_model-00002-of-00002.bin:  74% 2.60G/3.50G [00:15<00:03, 257MB/s]
# pytorch_model-00002-of-00002.bin:  75% 2.63G/3.50G [00:15<00:03, 232MB/s]
# pytorch_model-00002-of-00002.bin:  76% 2.66G/3.50G [00:15<00:03, 239MB/s]
# pytorch_model-00002-of-00002.bin:  77% 2.69G/3.50G [00:15<00:03, 247MB/s]
# pytorch_model-00002-of-00002.bin:  78% 2.73G/3.50G [00:16<00:03, 256MB/s]
# pytorch_model-00002-of-00002.bin:  79% 2.76G/3.50G [00:16<00:03, 243MB/s]
# pytorch_model-00002-of-00002.bin:  80% 2.79G/3.50G [00:16<00:03, 232MB/s]
# pytorch_model-00002-of-00002.bin:  81% 2.82G/3.50G [00:16<00:03, 219MB/s]
# pytorch_model-00002-of-00002.bin:  81% 2.85G/3.50G [00:16<00:02, 219MB/s]
# pytorch_model-00002-of-00002.bin:  82% 2.88G/3.50G [00:16<00:02, 220MB/s]
# pytorch_model-00002-of-00002.bin:  83% 2.92G/3.50G [00:17<00:02, 196MB/s]
# pytorch_model-00002-of-00002.bin:  84% 2.94G/3.50G [00:17<00:03, 186MB/s]
# pytorch_model-00002-of-00002.bin:  84% 2.96G/3.50G [00:17<00:02, 185MB/s]
# pytorch_model-00002-of-00002.bin:  85% 2.99G/3.50G [00:17<00:02, 190MB/s]
# pytorch_model-00002-of-00002.bin:  86% 3.02G/3.50G [00:17<00:02, 200MB/s]
# pytorch_model-00002-of-00002.bin:  87% 3.04G/3.50G [00:17<00:02, 196MB/s]
# pytorch_model-00002-of-00002.bin:  87% 3.06G/3.50G [00:17<00:02, 197MB/s]
# pytorch_model-00002-of-00002.bin:  88% 3.09G/3.50G [00:17<00:01, 214MB/s]
# pytorch_model-00002-of-00002.bin:  89% 3.12G/3.50G [00:18<00:01, 216MB/s]
# pytorch_model-00002-of-00002.bin:  90% 3.16G/3.50G [00:18<00:01, 210MB/s]
# pytorch_model-00002-of-00002.bin:  91% 3.19G/3.50G [00:18<00:01, 201MB/s]
# pytorch_model-00002-of-00002.bin:  92% 3.22G/3.50G [00:18<00:01, 202MB/s]
# pytorch_model-00002-of-00002.bin:  93% 3.25G/3.50G [00:18<00:01, 213MB/s]
# pytorch_model-00002-of-00002.bin:  94% 3.28G/3.50G [00:18<00:01, 208MB/s]
# pytorch_model-00002-of-00002.bin:  95% 3.31G/3.50G [00:18<00:00, 217MB/s]
# pytorch_model-00002-of-00002.bin:  96% 3.34G/3.50G [00:19<00:00, 216MB/s]
# pytorch_model-00002-of-00002.bin:  96% 3.38G/3.50G [00:19<00:00, 214MB/s]
# pytorch_model-00002-of-00002.bin:  97% 3.41G/3.50G [00:19<00:00, 198MB/s]
# pytorch_model-00002-of-00002.bin:  98% 3.43G/3.50G [00:19<00:00, 191MB/s]
# pytorch_model-00002-of-00002.bin:  99% 3.45G/3.50G [00:19<00:00, 181MB/s]
# pytorch_model-00002-of-00002.bin: 100% 3.50G/3.50G [00:19<00:00, 175MB/s]
# Downloading shards: 100% 2/2 [01:17<00:00, 38.60s/it]
# Loading checkpoint shards: 100% 2/2 [00:57<00:00, 28.61s/it]
# generation_config.json: 100% 162/162 [00:00<00:00, 1.09MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# tokenizer_config.json: 100% 749/749 [00:00<00:00, 3.95MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 133MB/s]
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 3.01MB/s]
# 2024-07-04 16:20:41 - Created default chainlit markdown file at /content/chainlit.md
# 2024-07-04 16:20:41 - Your app is available at http://localhost:8000
# 2024-07-04 16:25:48 - Translation file for vi not found. Using default translation en-US.
# 2024-07-04 16:25:49 - Translated markdown file for vi not found. Defaulting to chainlit.md.
